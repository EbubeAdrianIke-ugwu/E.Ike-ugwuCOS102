# %% [markdown]
# Pseudocode for store checkout after purchase
#
# BEGIN
# INPUT Number_of_items
# FOR each item
# INPUT Price 1
# INPUT Price 2
# INPUT Price 3
# COMPUTE Total_Price=Price 1+Price 2+Price 3
# DISPLAY Total
# INPUT Payment
# IF payment >= total THEN
# change = payment - total
# Display "Payment successful"
# Display change
# ELSE
# Display "Not enough money"
# END

# %% [markdown]
# ![Untitled Diagram.png](attachment:ef68f940-ec62-4825-97b4-04a20b7ee81a.png)

# %% [markdown]
# Flow chart of my morning routine
# ![Untitled Diagram.png](attachment:baa4ec6b-6b83-46ae-a213-45a410685a86.png)

# %% [markdown]
# Psedocode to Input Two Names and Their Ages, Then Swap the Ages
# START
# Input name1
# Input age1
# Input name2
# Input age2
# Temp = age1
# age1 = age2
# age2 = temp
# Display name1, age1
# Display name2, age2
# END
